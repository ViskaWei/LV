# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import h5py
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
PROJECT_PATH = '../'
import sys
sys.path.insert(0, PROJECT_PATH)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
from lv.dnn.dnn_ALL import DNN_ALL
# Out:
# 2021-10-31 12:21:21.263083: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-31 12:21:24.295450: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2021-10-31 12:21:25.592169: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:8a:00.0 name: NVIDIA Tesla V100-SXM2-16GB computeCapability: 7.0
# coreClock: 1.53GHz coreCount: 80 deviceMemorySize: 15.78GiB deviceMemoryBandwidth: 836.37GiB/s
# 2021-10-31 12:21:25.592247: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2021-10-31 12:21:25.600504: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2021-10-31 12:21:25.600582: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2021-10-31 12:21:25.602595: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2021-10-31 12:21:25.603246: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2021-10-31 12:21:25.604305: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2021-10-31 12:21:25.606036: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2021-10-31 12:21:25.606310: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2021-10-31 12:21:25.608225: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0

# %%
d = DNN_ALL(arms=["BL"], grid=0, top=60, pdx=[0,1,2], N_test=1000, pc_name="_10k", gpu=3)

# %%
d.prepare(N_train=10000, isNoisy=1)

# %%
d.run(lr=0.01, dp=0.1, ep=1000,)
# Out:
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0439 | mean_: 0.0439 | val_l: 0.0076 | val_m: 0.0076 | lr: 0.0100 |
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0475 | mean_: 0.0475 | val_l: 0.0155 | val_m: 0.0155 | lr: 0.0100 |
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0447 | mean_: 0.0447 | val_l: 0.0098 | val_m: 0.0098 | lr: 0.0100 |
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0533 | mean_: 0.0533 | val_l: 0.0204 | val_m: 0.0204 | lr: 0.0100 |
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0462 | mean_: 0.0462 | val_l: 0.0119 | val_m: 0.0119 | lr: 0.0100 |
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0435 | mean_: 0.0435 | val_l: 0.0108 | val_m: 0.0108 | lr: 0.0100 |

# %%
d.get_overlap_mat(plot=1)
