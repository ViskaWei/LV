# %%
# %load_ext autoreload
# %autoreload 2

# %%
PROJECT_PATH = '../'
import sys
sys.path.insert(0, PROJECT_PATH)

# %%
from lv.dnn.dnnpipeline import DNNPipeline

# %%
ddp = DNNPipeline(top=30)

# %%
ddp.run(ep=1000)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Layers: [90, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0001 | mean_: 0.0001 | val_l: 0.0002 | val_m: 0.0002 | lr: 0.0000 |
#  17%|█▋        | 1/6 [00:06<00:32,  6.56s/it]
# Layers: [90, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0001 | mean_: 0.0001 | val_l: 0.0001 | val_m: 0.0001 | lr: 0.0000 |
#  33%|███▎      | 2/6 [00:13<00:26,  6.72s/it]
# Layers: [90, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0001 | mean_: 0.0001 | val_l: 0.0002 | val_m: 0.0002 | lr: 0.0000 |
#  50%|█████     | 3/6 [00:20<00:20,  6.73s/it]
# Layers: [90, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0001 | mean_: 0.0001 | val_l: 0.0001 | val_m: 0.0001 | lr: 0.0000 |
#  67%|██████▋   | 4/6 [00:25<00:12,  6.08s/it]
# Layers: [90, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0001 | mean_: 0.0001 | val_l: 0.0001 | val_m: 0.0001 | lr: 0.0000 |
#  83%|████████▎ | 5/6 [00:31<00:06,  6.10s/it]
# Layers: [90, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0001 | mean_: 0.0001 | val_l: 0.0001 | val_m: 0.0001 | lr: 0.0000 |
# ...

# %%
ddp.get_contamination_mat()

# %%
R0, R1 = "C", "G"
ddp.plot_box_R0_R1(R0, R1, n_box=2, axs=None)

# %%
ddp40 = DNNPipeline(top=40)

# %%
ddp40.run(ep=1000)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Layers: [120, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0001 | mean_: 0.0001 | val_l: 0.0001 | val_m: 0.0001 | lr: 0.0000 |
#  17%|█▋        | 1/6 [00:05<00:27,  5.54s/it]
# Layers: [120, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0000 | mean_: 0.0000 | val_l: 0.0000 | val_m: 0.0000 | lr: 0.0000 |
#  33%|███▎      | 2/6 [00:10<00:21,  5.40s/it]
# Layers: [120, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0001 | mean_: 0.0001 | val_l: 0.0001 | val_m: 0.0001 | lr: 0.0000 |
#  50%|█████     | 3/6 [00:16<00:16,  5.55s/it]
# Layers: [120, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0001 | mean_: 0.0001 | val_l: 0.0001 | val_m: 0.0001 | lr: 0.0000 |
#  67%|██████▋   | 4/6 [00:22<00:11,  5.77s/it]
# Layers: [120, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0000 | mean_: 0.0000 | val_l: 0.0000 | val_m: 0.0000 | lr: 0.0000 |
#  83%|████████▎ | 5/6 [00:27<00:05,  5.33s/it]
# Layers: [120, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0001 | mean_: 0.0001 | val_l: 0.0001 | val_m: 0.0001 | lr: 0.0000 |
# ...

# %%
ddp40.get_contamination_mat()

# %%
R0, R1 = "C", "G"
ddp40.plot_box_R0_R1(R0, R1, n_box=2, axs=None)
