# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import h5py
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
PROJECT_PATH = '../'
import sys
sys.path.insert(0, PROJECT_PATH)

# %%
from lv.dnn.dnn_ALL import DNN_ALL

# %%
d = DNN_ALL(arms=["BL"], grid=0, top=60, pdx=[0,1,2], N_test=1000, pc_name="_10k")

# %%
d.prepare(N_train=10000, isNoisy=1)

# %%
d.run(lr=0.01, dp=0.1, ep=1000,)
# Out:
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0545 | mean_: 0.0545 | val_l: 0.0225 | val_m: 0.0225 | lr: 0.0010 |
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0555 | mean_: 0.0555 | val_l: 0.0250 | val_m: 0.0250 | lr: 0.0100 |
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0596 | mean_: 0.0596 | val_l: 0.0294 | val_m: 0.0294 | lr: 0.0100 |
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0677 | mean_: 0.0677 | val_l: 0.0408 | val_m: 0.0408 | lr: 0.0100 |
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0545 | mean_: 0.0545 | val_l: 0.0248 | val_m: 0.0248 | lr: 0.0100 |
# Layers: [60, 64, 32, 16, 3]
# | EP 1000 |loss: 0.0635 | mean_: 0.0635 | val_l: 0.0370 | val_m: 0.0370 | lr: 0.0001 |

# %%
d.get_overlap_mat(plot=1)
